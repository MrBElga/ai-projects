# %%
from keras.models import Sequential
from keras.layers import  Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from keras.layers import BatchNormalization
from keras.preprocessing.image import ImageDataGenerator
import numpy as np
from keras.preprocessing import image

# %%
cnn = Sequential()
cnn.add(Conv2D(32,(3,3), input_shape = (64,64,3), activation='relu'))
cnn.add(BatchNormalization())
cnn.add(MaxPooling2D(pool_size=(2,2)))


cnn.add(Flatten())
cnn.add(Dense(units=128, activation = 'relu'))
cnn.add(Dropout(0.2))
cnn.add(Dense(units=128, activation = 'relu'))
cnn.add(Dropout(0.2))
cnn.add(Dense(units=1, activation = 'sigmoid'))

cnn.compile(optimizer='adam',loss='binary_crossentropy',metrics=['binary_crossentropy'])

# %%
gerador_treino = ImageDataGenerator(rescale = 1./255,
                                    rotation_range = 7,
                                    horizontal_flip = True,
                                    shear_range = 0.2,
                                    height_shift_range = 0.07,
                                    zoom_range = 0.2)
gerador_teste = ImageDataGenerator(rescale=1./255)

# %%
base_treino = gerador_treino.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/gatocachorro/dataset/training_set',
                                                 target_size=(64,64),
                                                 batch_size = 2,
                                                 class_mode = 'binary'
                                                 )
# Out:
# Found 4000 images belonging to 2 classes.

# %%
base_teste = gerador_teste.flow_from_directory('/content/drive/MyDrive/Colab Notebooks/gatocachorro/dataset/test_set',
                                                 target_size=(64,64),
                                                 batch_size = 2,
                                                 class_mode = 'binary'
                                                 )
# Out:
# Found 1000 images belonging to 2 classes.

# %%
cnn.fit(base_treino,steps_per_epoch=4000/32, epochs = 10, validation_data = base_teste, validation_steps = 1000/32)
# Out:
# Epoch 1/10
# 125/125 [==============================] - 85s 627ms/step - loss: 1.7267 - binary_crossentropy: 1.7267 - val_loss: 0.7113 - val_binary_crossentropy: 0.7113
# Epoch 2/10
# 125/125 [==============================] - 39s 313ms/step - loss: 0.7877 - binary_crossentropy: 0.7877 - val_loss: 0.8132 - val_binary_crossentropy: 0.8132
# Epoch 3/10
# 125/125 [==============================] - 40s 321ms/step - loss: 0.7439 - binary_crossentropy: 0.7439 - val_loss: 0.8260 - val_binary_crossentropy: 0.8260
# Epoch 4/10
# 125/125 [==============================] - 44s 350ms/step - loss: 0.7589 - binary_crossentropy: 0.7589 - val_loss: 0.9629 - val_binary_crossentropy: 0.9629
# Epoch 5/10
# 125/125 [==============================] - 38s 302ms/step - loss: 0.7998 - binary_crossentropy: 0.7998 - val_loss: 0.6862 - val_binary_crossentropy: 0.6862
# Epoch 6/10
# ...
